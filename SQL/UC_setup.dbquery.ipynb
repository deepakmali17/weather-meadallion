-- %%
CREATE SCHEMA IF NOT EXISTS devdatabricksweather.bronze;

CREATE SCHEMA IF NOT EXISTS devdatabricksweather.silver;

CREATE SCHEMA IF NOT EXISTS devdatabricksweather.gold;

GRANT USE CATALOG
ON CATALOG devdatabricksweather
TO `ab424b91-009d-4f21-8352-727907ef9464`;

GRANT USE SCHEMA
ON SCHEMA devdatabricksweather.bronze
TO `ab424b91-009d-4f21-8352-727907ef9464`;

GRANT  ALL PRIVILEGES
ON TABLE devdatabricksweather.bronze.bronze_table
TO `ab424b91-009d-4f21-8352-727907ef9464`;


GRANT USE SCHEMA
ON SCHEMA devdatabricksweather.silver
TO `ab424b91-009d-4f21-8352-727907ef9464`;


GRANT  ALL PRIVILEGES
ON TABLE devdatabricksweather.silver.weather_hourly
TO `ab424b91-009d-4f21-8352-727907ef9464`;

GRANT USE SCHEMA
ON SCHEMA devdatabricksweather.gold
TO `ab424b91-009d-4f21-8352-727907ef9464`;
